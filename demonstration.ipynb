# %% [markdown]
# # Visualizing Agents
# ---

# %% [markdown]
# All code designed and written by
# Troy Chibbaro – tbc41
# Rishi Jammalamadaka - rj433
#
# Each of us contributed an equal amount work via virtual collaboration.

# %% [markdown]
# Run Agent 1

# %%
from Maze import Maze
import matplotlib.pyplot as plt
from AgentOne import AgentOne
new_maze_1 = Maze(fire_modifier=0.20, mazeSize=75)
fig =plt.figure(figsize=(15,15))
plt.rc('grid', linestyle="-", color='gray', linewidth=2)
grid = plt.gca()
grid.axes.xaxis.set_ticklabels([])
grid.axes.yaxis.set_ticklabels([])
grid.set_ylim(ymin=new_maze_1.mazeSize-0.5)
grid.set_xlim(xmin=-0.5)
plt.grid(True)
agent_one = AgentOne(new_maze_1)
agent_one.move()
new_maze_1.plot_grid()

# %% [markdown]
# Run Agent 2

# %%
from AgentTwo import AgentTwo
new_maze_2 = Maze(fire_modifier=0.20, mazeSize=75)
fig=plt.figure(figsize=(15,15))
plt.rc('grid', linestyle="-", color='gray', linewidth=2)
grid = plt.gca()
grid.axes.xaxis.set_ticklabels([])
grid.axes.yaxis.set_ticklabels([])
grid.set_ylim(ymin=new_maze_2.mazeSize-0.5)
grid.set_xlim(xmin=-0.5)
plt.grid(True)
agent_two = AgentTwo(new_maze_2)
agent_two.move()
new_maze_2.plot_grid()

# %% [markdown]
# Agent Three

# %%
from AgentThree import AgentThree
new_maze_3 = Maze(fire_modifier=0.15, mazeSize=75)
fig=plt.figure(figsize=(15,15))
plt.rc('grid', linestyle="-", color='gray', linewidth=2)
grid = plt.gca()
grid.axes.xaxis.set_ticklabels([])
grid.axes.yaxis.set_ticklabels([])
grid.set_ylim(ymin=new_maze_3.mazeSize-0.5)
grid.set_xlim(xmin=-0.5)
plt.grid(True)
agent_three = AgentThree(new_maze_3)
agent_three.move()
new_maze_3.plot_grid()

# %%
from AgentFour import AgentFour
new_maze_4 = Maze(fire_modifier=0.15, mazeSize=63)
fig=plt.figure(figsize=(15,15))
plt.rc('grid', linestyle="-", color='gray', linewidth=2)
grid = plt.gca()
grid.axes.xaxis.set_ticklabels([])
grid.axes.yaxis.set_ticklabels([])
grid.set_ylim(ymin=new_maze_4.mazeSize-0.5)
grid.set_xlim(xmin=-0.5)
plt.grid(True)
agent_four = AgentFour(new_maze_4)
agent_four.move()
new_maze_4.plot_grid()
